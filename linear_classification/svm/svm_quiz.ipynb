# %% [markdown]
# # Introduction

# %%
from jupyterquiz import display_quiz
import json
from base64 import b64encode

def get_spanned_encoded_q(q, q_name):
    byte_code = b64encode(bytes(json.dumps(q), 'utf8'))
    return f'<span style="display:none" id="{q_name}">{byte_code.decode()}</span>'

i =   [{
        "question": "Which statements accurately describe the maximal margin classifier?",
        "type": "many_choice",
        "answers": [
            {
                "answer": "It is designed for non-linearly separable data.",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "  It maximizes the margin between two classes.",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": "  It tends to overfit and is heavily reliant on support vectors.",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": "It can handle large datasets efficiently.",
                "correct": False,
                "feedback": "Wrong."
            }
        ]
    }]
display_quiz(i)
# Out:
# <div id="ZJeLbKdlEFho" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #ZJeLbKdlEFho {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(i, "i")
# Out:
# '<span style="display:none" id="i">...</span>'

# %%
i1 =   [{
        "question": "What are characteristics of the support vector classifier?",
        "type": "many_choice",
        "answers": [
            {
                "answer": "It minimizes the margin between classes.",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": " It is less sensitive to noise in the data.",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "It allows for some misclassification, known as the 'Soft Margin Classifier.' ",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": "It is an extension of the maximal margin classifier.",
                "correct": True,
                "feedback": "Correct."
            }
        ]
    }]
display_quiz(i1)
# Out:
# <div id="DhOhcsYaTlwF" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #DhOhcsYaTlwF {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(i1, "i1")
# Out:
# '<span style="display:none" id="i1">...</span>'

# %%
i2 =   [{
        "question": "What advantages are associated with the support vector machine compared to the support vector classifier?",
        "type": "many_choice",
        "answers": [
            {
                "answer": " It can handle non-linearly separable data",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": "  It is less robust to noise in the data.",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "It can handle large datasets.",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "It uses a kernel function to transform input data.",
                "correct": True,
                "feedback": "Correct."
            }
        ]
    }]
display_quiz(i2)
# Out:
# <div id="LSLqOxRBxNey" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #LSLqOxRBxNey {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(i2, "i2")
# Out:
# '<span style="display:none" id="i2">...</span>'

# %% [markdown]
# # Understanding SVM Basics

# %%
a =   [{
        "question": "What does SVM stand for?",
        "type": "many_choice",
        "answers": [
            {
                "answer": "Simple Vector Machine",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": " Support Vector Machine",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": " Supervised Vector Model",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "Singular Value Method",
                "correct": False,
                "feedback": "Wrong."
            }
        ]
    }]
display_quiz(a)
# Out:
# <div id="ZkpbfIDhqtLs" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #ZkpbfIDhqtLs {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(a, "a")
# Out:
# '<span style="display:none" id="a">...</span>'

# %%
from jupyterquiz import display_quiz
a2 =   [{
        "question": "In SVM, what is a support vector?",
        "type": "many_choice",
        "answers": [
            {
                "answer": "Any data point in the dataset",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": " Data points that lie closest to the decision boundary",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": " Outliers in the dataset",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "All data points equally contribute to the model",
                "correct": False,
                "feedback": "Wrong."
            }
        ]
    }]
display_quiz(a2)
# Out:
# <div id="sdNcwKXhOoTS" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #sdNcwKXhOoTS {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(a2, "a2")
# Out:
# '<span style="display:none" id="a2">...</span>'

# %%
from jupyterquiz import display_quiz
a3 =   [{
        "question": "Which of the following are characteristics of support vectors in SVM? (Select all that apply)",
        "type": "many_choice",
        "answers": [
            {
                "answer": "Lie closest to the decision boundary",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": " Outliers in the dataset",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": " Determine the position of the decision boundary",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": "Contribute significantly to the model's parameters",
                "correct": False,
                "feedback": "Wrong."
            }
        ]
    }]
display_quiz(a3)
# Out:
# <div id="hXRhQMpleITt" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #hXRhQMpleITt {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(a3, "a3")
# Out:
# '<span style="display:none" id="a3">...</span>'

# %%
c2 = [{
        "question": "How many features does a hyperplane have in a support vector machine when the input features are 5? Tip: (Answer is whole number)",
        "type": "numeric",
        "precision": 10,
        "answers": [
            {
                "type": "value",
                "value": 4,
                "correct": True,
                "feedback": "Correct."
            },
            {
                "type": "range",
                "range": [ -100000000, -0.000000001], 
                "correct": False,
                "feedback": "Wrong. Try again."
            },{
                "type": "range",
                "range": [  4.0000001, 100000000], 
                "correct": False,
                "feedback": "Wrong. Try again."
            }
        ]
    } ]
display_quiz(c2)
# Out:
# <div id="mKrHcQqZfFyG" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #mKrHcQqZfFyG {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(c2, "c2")
# Out:
# '<span style="display:none" id="c2">...</span>'

# %%
a4 =   [{
        "question": "What is the role of the decision boundary in SVM? (Select all that apply)",
        "type": "many_choice",
        "answers": [
            {
                "answer": " Separates different classes",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": " Minimizes the margin between classes",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "  Has no impact on classification accuracy",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": " Maximizes the margin between classes",
                "correct": True,
                "feedback": "Correct."
            }
        ]
    }]
display_quiz(a4)
# Out:
# <div id="hJNejAVhvCOi" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #hJNejAVhvCOi {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(a4, "a4")
# Out:
# '<span style="display:none" id="a4">...</span>'

# %%
a5 = [{
        "question": "What is the default value of the C parameter in SVM? (Answer is whole number)",
        "type": "numeric",
        "precision": 3,
        "answers": [
            {
                "type": "value",
                "value": 1,
                "correct": True,
                "feedback": "Correct."
            },
            {
                "type": "range",
                "range": [ -100000000, 0.99999999], 
                "correct": False,
                "feedback": "Wrong. Try again."
            },{
                "type": "range",
                "range": [ 1.00000001, 100000000], 
                "correct": False,
                "feedback": "Wrong. Try again."
            }
        ]
    } ]
display_quiz(a5)
# Out:
# <div id="UVKaDlkiSbFE" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #UVKaDlkiSbFE {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(a5, "a5")
# Out:
# '<span style="display:none" id="a5">...</span>'

# %% [markdown]
# # Understanding the mathematics behind SVM

# %%
b =   [{
        "question": "What is the primary purpose of SVM?",
        "type": "many_choice",
        "answers": [
            {
                "answer": "Classification",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": "Regression",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "Clustering",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": " Dimensionality reduction",
                "correct": False,
                "feedback": "Wrong."
            }
        ]
    }]
display_quiz(b)
# Out:
# <div id="IqQyWOffSfEp" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #IqQyWOffSfEp {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(b, "b")
# Out:
# '<span style="display:none" id="b">...</span>'

# %%
b2 =   [{
        "question": "Which mathematical concept is crucial for SVM?",
        "type": "many_choice",
        "answers": [
            {
                "answer": "Trigonometry",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "Matrix multiplication",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "Exponential function",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": " Dot product",
                "correct": True,
                "feedback": "Correct."
            }
        ]
    }]
display_quiz(b2)
# Out:
# <div id="XwAvbYFOZNxG" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #XwAvbYFOZNxG {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(b2, "b2")
# Out:
# '<span style="display:none" id="b2">...</span>'

# %%
b4 =   [{
        "question": "What does the maximum margin in SVM refer to?",
        "type": "many_choice",
        "answers": [
            {
                "answer": "The distance between support vectors",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "The distance between the hyperplane and the nearest data point",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "The angle between vectors",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "The width of the decision boundary",
                "correct": True,
                "feedback": "Correct."
            }
        ]
    }]
display_quiz(b4)
# Out:
# <div id="ucXJBhgEDfhK" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #ucXJBhgEDfhK {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(b4, "b4")
# Out:
# '<span style="display:none" id="b4">...</span>'

# %%
c = [{
        "question": "What is the minimum possible value for the margin in SVM? Tip: (Answer is whole number)",
        "type": "numeric",
        "precision": 10,
        "answers": [
            {
                "type": "value",
                "value": 0,
                "correct": True,
                "feedback": "Correct. That is the minimum."
            },
            {
                "type": "range",
                "range": [ -100000000, -0.000000001], 
                "correct": False,
                "feedback": "Wrong. Try again."
            },{
                "type": "range",
                "range": [  0.000000001, 100000000], 
                "correct": False,
                "feedback": "Wrong. Try again."
            }
        ]
    } ]
display_quiz(c)
# Out:
# <div id="lngbQQgTnhpF" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #lngbQQgTnhpF {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(c, "c")
# Out:
# '<span style="display:none" id="c">...</span>'

# %%
b5 =   [{
        "question": "Which type of SVM allows for misclassification of some data points?",
        "type": "many_choice",
        "answers": [
            {
                "answer": "Hard Margin SVM",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "Linear SVM",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "Soft Margin SVM",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": "Non-linear SVM",
                "correct": False,
                "feedback": "Wrong."
            }
        ]
    }]
display_quiz(b5)
# Out:
# <div id="yPLTlhDbXuWj" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #yPLTlhDbXuWj {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(b5, "b5")
# Out:
# '<span style="display:none" id="b5">...</span>'

# %%
b6 =   [{
        "question": "What is the role of the kernel trick in SVM?",
        "type": "many_choice",
        "answers": [
            {
                "answer": "It simplifies the decision boundary",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "It reduces overfitting",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "It transforms data into a higher-dimensional space",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": "It computes the dot product efficiently",
                "correct": False,
                "feedback": "Wrong."
            }
        ]
    }]
display_quiz(b6)
# Out:
# <div id="TJzKDMUOdnGl" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #TJzKDMUOdnGl {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(b6, "b6")
# Out:
# '<span style="display:none" id="b6">...</span>'

# %%
b7 =   [{
        "question": "What is the purpose of the C hyperparameter in SVM? (Select all that apply)",
        "type": "many_choice",
        "answers": [
            {
                "answer": "To determine the number of support vectors",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "To control the regularization strength",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": "To determine the number of support vectors",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": "To set the learning rate",
                "correct": False,
                "feedback": "Wrong."
            }
        ]
    }]
display_quiz(b7)
# Out:
# <div id="QdMiDhEuQHjK" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #QdMiDhEuQHjK {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(b7, "b7")
# Out:
# '<span style="display:none" id="b7">...</span>'

# %%
c1 = [{
        "question": "Given a SVM model with a linear kernel, if the equation of the hyperplane is 4x1 - 3x2 + 12 = 0, calculate the distance between the hyperplane and the origin using the formula for the distance from a point to a plane.",
        "type": "numeric",
        "precision": 10,
        "answers": [
            {
                "type": "value",
                "value": 12/5,
                "correct": True,
                "feedback": "Correct. You are pretty good!"
            },
            {
                "type": "range",
                "range": [ -100000000, -0.000000001], 
                "correct": False,
                "feedback": "Wrong. Try again."
            },{
                "type": "range",
                "range": [  0.000000001, 100000000], 
                "correct": False,
                "feedback": "Wrong. Try again."
            }
        ]
    } ]
display_quiz(c1)
# Out:
# <div id="ynJMktlOmbxY" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #ynJMktlOmbxY {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(c1, "c1")
# Out:
# '<span style="display:none" id="c1">...</span>'

# %%
b8 =   [{
        "question": "Which kernel function is commonly used for non-linear SVMs?",
        "type": "many_choice",
        "answers": [
            {
                "answer": "Linear kernel",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "Polynomial kernel",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "Radial basis function (RBF) kernel",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": "Sigmoid kernel",
                "correct": False,
                "feedback": "Wrong."
            }
        ]
    }]
display_quiz(b8)
# Out:
# <div id="CUWLofZeFRKf" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #CUWLofZeFRKf {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(b8, "b8")
# Out:
# '<span style="display:none" id="b8">...</span>'

# %%
b9 =   [{
        "question": "What is the purpose of the slack variables in SVM? (Select all that apply)",
        "type": "many_choice",
        "answers": [
            {
                "answer": "To determine the number of support vectors",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "To adjust the kernel function",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "To control the regularization strength",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": "To penalize misclassified data points",
                "correct": True,
                "feedback": "Correct."
            }
        ]
    }]
display_quiz(b9)
# Out:
# <div id="TZoWfcrQReyQ" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #TZoWfcrQReyQ {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(b9, "b9")
# Out:
# '<span style="display:none" id="b9">...</span>'

# %%
b10 =   [{
        "question": "Which SVM variant is suitable for handling noisy data?",
        "type": "many_choice",
        "answers": [
            {
                "answer": "Hard Margin SVM",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "Linear SVM",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "Soft Margin SVM",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": "Non-linear SVM",
                "correct": False,
                "feedback": "Wrong."
            }
        ]
    }]
display_quiz(b10)
# Out:
# <div id="AOiQhflFeyIR" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #AOiQhflFeyIR {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(b10, "b10")
# Out:
# '<span style="display:none" id="b10">...</span>'

# %%
b11 =   [{
        "question": "Which kernel function is suitable for text classification tasks? (Select all that apply)",
        "type": "many_choice",
        "answers": [
            {
                "answer": "Linear kernel",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": "Polynomial kernel",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "Radial basis function (RBF) kernel",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": "Sigmoid kernel",
                "correct": False,
                "feedback": "Wrong."
            }
        ]
    }]
display_quiz(b11)
# Out:
# <div id="upxvJOyiidAv" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #upxvJOyiidAv {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(b11, "b11")
# Out:
# '<span style="display:none" id="b11">...</span>'

# %%
b12 =   [{
        "question": "Which SVM variant is suitable for handling imbalanced datasets?",
        "type": "many_choice",
        "answers": [
            {
                "answer": "Hard Margin SVM",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "Linear SVM",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "Non-linear SVM",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "Soft Margin SVM",
                "correct": True,
                "feedback": "Correct."
            }
        ]
    }]
display_quiz(b12)
# Out:
# <div id="iwEjgFbeSMEn" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #iwEjgFbeSMEn {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(b12, "b12")
# Out:
# '<span style="display:none" id="b12">...</span>'

# %%
b13 =   [{
        "question": "In SVM, what is the purpose of the gamma parameter in the RBF kernel? (Select all that apply)",
        "type": "many_choice",
        "answers": [
            {
                "answer": "To adjust the regularization strength",
                "correct": False,
                "feedback": "Wrong."
            },
            {
                "answer": "To determine the number of support vectors",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": "To control the kernel width",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": "To set the learning rate",
                "correct": False,
                "feedback": "Wrong."
            }
        ]
    }]
display_quiz(b13)
# Out:
# <div id="iAhMBCclDhsB" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #iAhMBCclDhsB {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(b13, "b13")
# Out:
# '<span style="display:none" id="b13">...</span>'
