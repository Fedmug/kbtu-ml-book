# %% [markdown]
# # Applications of ML
#
# ## Computer vision
#
# ### Image classification
#
# ```{image} https://ars.els-cdn.com/content/image/1-s2.0-S1474034619305531-gr4.jpg
# :alt: img-cat-or-dog
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```

# %% [markdown]
# ### Object detection
#
# ```{image} https://www.perficient.com/-/media/images/insights/hero-images/research_image-recognition-accuracy-study_hero.ashx?h=931&iar=0&w=1400&hash=E0AED7417F234D3C66F9037149BB7612
# :alt: img-detection
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```

# %% [markdown]
# ### Semantic segmentation
#
# ```{image} https://deeplobe.ai/wp-content/uploads/2023/06/Image-Segmentation_-What-Are-the-Most-Interesting-Applications_.png
# :alt: depth-estimation
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```
#
#
# ### Depth estimation
#
# ```{image} https://cdn.prod.website-files.com/645cec60ffb18d5ebb37da4b/65e822f311bddf1953d2c9fd_Picture3.jpg
# :alt: depth-estimation
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```

# %% [markdown]
# ### Action recognition
#
# ```{image} https://miro.medium.com/v2/resize:fit:1400/1*EvxO1sdZ1DCLfDxQNTiflQ.png
# :alt: action-recognition
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```
#
# ### Image captioning
#
# ```{image} https://repository-images.githubusercontent.com/83958320/8f162500-8ace-11e9-94ee-0b86d27bbc5e
# :alt: image-captioning
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```

# %% [markdown]
# ## Natural language processing
#
# ### Sentiment analysis
#
# ```{image} https://vitalflux.com/wp-content/uploads/2021/10/sentiment-analysis-machine-learning-techniques.png
# :alt: sentiment-analysis
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```
#
# ### Machine translation
#
# ```{image} https://ehlion.com/wp-content/uploads/2020/10/Machine-Translation.jpg
# :alt: machine-translation
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```
#
# ### Text summarization
#
# ```{image} https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTM2YJJNIY5fLgF7nJJ4a8FurUHeKO6oXZFBA&s
# :alt: text-summarization
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```
#
# ### Speech recognition
# ```{image} https://developer-blogs.nvidia.com/wp-content/uploads/2019/12/automatic-speech-recognition_updated.png
# :alt: speech-recognition
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```
#
# ### Spam filtering
#
# ```{image} https://www.spcdn.org/images/spam-filter1.jpg
# :alt: spam-filtering
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```

# %% [markdown]
# ## Finance
#
# ### Credit scoring
# ```{image} https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQzKB0N4TlZH-ooRz_br4JnfkXeFnYmjgsFketeQFr8ESqzTakiOEoNt0qWDu41grsMpyI&usqp=CAU
# :alt: credit-scoring
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```
#
# ### Fraud detection
#
# ```{image} https://news.mit.edu/sites/default/files/images/201809/MIT-Fraud-Detection-PRESS.jpg
# :alt: fraud-detection
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```
#
# ### Algorithmic trading
#
# ```{image} https://img.etimg.com/thumb/width-1200,height-900,imgsize-434644,resizemode-75,msid-79821832/markets/stocks/news/5-strategies-to-buy-and-sell-stocks-using-algo-trading.jpg
# :alt: algo-trading
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```

# %% [markdown]
# ## Recommendation systems
#
# ```{image} https://vitalflux.com/wp-content/uploads/2022/08/collaborative-filtering-recommender-system.png
# :alt: recommend
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```

# %% [markdown]
# ## Robotics
#
# ```{image} https://bostondynamics.com/wp-content/uploads/2023/05/spot-explorer-web-2.jpg
# :alt: robotics
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```

# %% [markdown]
# ## Playing games
#
# ```{image} https://c.files.bbci.co.uk/0D9B/production/_88738430_pic1go.jpg
# :alt: img-recognition
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```
#
# <!---
# ```{admonition} TODO
# :class: warning
# * Add some text description
# * Add some code
# * Add more applications
# * Add more morden stuff like chatGPT and generative AI
# * The interactive quizzes and plots are probably redundant here
# ```
# --->

# %% [markdown]
# ## Generative AI
#
# ### Content creation
#
# ```{image} https://media.licdn.com/dms/image/D5612AQFoxSZYLjV_EA/article-cover_image-shrink_720_1280/0/1677588476245?e=2147483647&v=beta&t=5WT3HMuBEmRSB9aJY-gUJkivFbH7DvkIH4LWk9T7u1Y
# :alt: chat-gpt
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```
#
# ### Image generation
#
# ```{image} https://s0.rbk.ru/v6_top_pics/media/img/3/69/346971151176693.jpeg
# :alt: image-gen
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```
#
# ### Deep fake
#
# ```{image} https://ichef.bbci.co.uk/news/976/cpsprodpb/14A0D/production/_129139448_68a836ea-f568-431d-862a-b04d839852e3.png
# :alt: deep-fake
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```
#
# ### Music generation
#
# ```{image} https://cdn.analyticsvidhya.com/wp-content/uploads/2020/01/auto-music-.jpg
# :alt: music-gen
# :class: bg-primary mb-1
# :width: 500px
# :align: center
# ```
