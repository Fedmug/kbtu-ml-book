# %%
from jupyterquiz import display_quiz
import json
from base64 import b64encode

def get_spanned_encoded_q(q, q_name):
    byte_code = b64encode(bytes(json.dumps(q), 'utf8'))
    return f'<span style="display:none" id="{q_name}">{byte_code.decode()}</span>'

# %%
q_b_a = [{
    "question": "How does a Naive Bayes classifier calculate the probability of an event, and what are the key steps involved in this process?",
    "type": "many_choice",
    "answers": [
        {
            "answer": "It relies on deep learning techniques exclusively",
            "correct": False,
            "feedback": "Incorrect"
        },
        {
            "answer": "It uses unsupervised learning for probability estimation",
            "correct": False,
            "feedback": "Incorrect"
        },
        {
            "answer": "It ignores probability calculations and relies solely on feature independence",
            "correct": False,
            "feedback": "Incorrect"
        },
        {
            "answer": "It calculates probabilities for informed classification.",
            "correct": True,
            "feedback": "Correct"
        },
    ]
}]

# %%
display_quiz(q_b_a)
# Out:
# <div id="towwKHRfFXSN" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...

# %%
get_spanned_encoded_q(q_b_a, "q_b_a")
# Out:
# '<span style="display:none" id="q_b_a">...</span>'

# %%
q_b_b = [{
    "question": "When prioritizing classification accuracy without generating new samples, which type of model is often preferred?",
    "type": "many_choice",
    "answers": [
        {
            "answer": "Discriminative; logistic regression estimates 𝑝(𝒙|𝑦)𝑝(𝑦)",
            "correct": False,
            "feedback": "Incorrect"  
        },
        {
            
            "answer": "Discriminative; logistic regression learns 𝑝(𝑦|𝒙,𝒘)",
            "correct": True,
            "feedback": "Correct"
        },
        {
            "answer": "Generative; logistic regression calculates the joint distribution",
            "correct": False,
            "feedback": "Incorrect"
        },
        {
            "answer": "Generative; logistic regression focuses on missing data",
            "correct": False,
            "feedback": "Incorrect"
        },
    ]
}]

# %%
display_quiz(q_b_b)
# Out:
# <div id="JPhyYtputmmD" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...

# %%
get_spanned_encoded_q(q_b_b, "q_b_b")

# %%
q_b_c = [{
    "question": "What observation can be made regarding the assumption of feature independence (naive assumption) in the Naive Bayes Classifier, and how does it impact the model's effectiveness?",
    "type": "many_choice",
    "answers": [
        {
            "answer": "Underestimates model effectiveness in practical tasks",
            "correct": False,
            "feedback": "Incorrect"  
        },
        {
            
            "answer": "Increases model complexity, reducing effectiveness",
            "correct": False,
            "feedback": "Incorrect"
        },
        {
            "answer": "Leads to precise predictions in limited cases",
            "correct": False,
            "feedback": "Incorrect"
        },
        {
            "answer": "Reduces computational complexity, maintaining surprising effectiveness",
            "correct": True,
            "feedback": "Correct"
        },
    ]
}]

# %%
display_quiz(q_b_c)
# Out:
# <div id="QilbymsiVGbE" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...

# %%
get_spanned_encoded_q(q_b_c, "q_b_c")

# %%
q_b_d = [{
    "question": "Explain the difference between the Multinomial Naive Bayes and Gaussian Naive Bayes variants of the Naive Bayes Classifier, Under what circumstances would you prefer to use one variant over the other, and why?",
    "type": "many_choice",
    "answers": [
        {
            "answer": "Multinomial Naive Bayes is preferred for image classification, while Gaussian Naive Bayes is more suitable for text classification tasks",
            "correct": False,
            "feedback": "Incorrect"  
        },
        {
            
            "answer": "Multinomial Naive Bayes assumes a Gaussian distribution for the features, making it suitable for continuous data, while Gaussian Naive Bayes is tailored for discrete data with multiple categories",
            "correct": False,
            "feedback": "Incorrect"
        },
        {
            "answer": "Multinomial Naive Bayes is suitable for discrete data with multiple categories, while Gaussian Naive Bayes is designed for continuous data with a normal distribution",
            "correct": True,
            "feedback": "Correct"
        },
        {
            "answer": "Multinomial Naive Bayes is specifically designed for binary classification tasks, whereas Gaussian Naive Bayes is versatile and applicable to both binary and multi-class problems",
            "correct": False,
            "feedback": "Incorrect"
        },
    ]
}]

# %%
display_quiz(q_b_d)
# Out:
# <div id="pXbLFzaZIMLe" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...

# %%
get_spanned_encoded_q(q_b_d, "q_b_d")
