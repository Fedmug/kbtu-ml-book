# %%
from jupyterquiz import display_quiz
import json
from base64 import b64encode
from matplotlib import pyplot as plt
from matplotlib import image as mpimg

def get_spanned_encoded_q(q, q_name):
    byte_code = b64encode(bytes(json.dumps(q), 'utf8'))
    return f'<span style="display:none" id="{q_name}">{byte_code.decode()}</span>'

# %%
q1 = [{
        "question": "Why are traditional feedforward neural networks not suitable for sequential data?",
        "type": "many_choice",
        "answers": [
            {
                "answer": "They assume that all inputs are independent of each other.",
                "correct": True,
                "feedback": "Correct! Traditional feedforward networks assume input independence and do not maintain state across inputs."
            },
            {
                "answer": "They can only process numerical data.",
                "correct": False,
                "feedback": "Incorrect. Feedforward neural networks can process various types of encoded data, not just numerical."
            },
            {
                "answer": "They use too much computational power.",
                "correct": False,
                "feedback": "Incorrect. While computational power can be a concern, it's not the reason they are unsuitable for sequential data."
            },
            {
                "answer": "They are too easy to train.",
                "correct": False,
                "feedback": "Incorrect. The ease or difficulty of training is not the issue when it comes to processing sequential data."
            }
        ]
    }]

# %%
display_quiz(q1)
# Out:
# <div id="CmAHeVIMXRyx" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #CmAHeVIMXRyx {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(q1, "q1")
# Out:
# '<span style="display:none" id="q1">...</span>'

# %%
display_quiz("#q1")
# Out:
# <div id="VFJWrZknUFhj" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #VFJWrZknUFhj {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
q2 = [{
        "question": "What problem do RNNs face that LSTMs are designed to overcome?",
        "type": "many_choice",
        "answers": [
            {
                "answer": "Overfitting to the training data.",
                "correct": False,
                "feedback": "Incorrect. Overfitting is a general problem in machine learning but not specific to the problem LSTMs are designed to solve."
            },
            {
                "answer": "The vanishing and exploding gradient problem.",
                "correct": True,
                "feedback": "Correct! LSTMs are designed to avoid long-term dependency issues like vanishing and exploding gradients."
            },
            {
                "answer": "The inability to process images.",
                "correct": False,
                "feedback": "Incorrect. The focus of LSTMs is sequential data, not image processing."
            },
            {
                "answer": "High latency in predictions.",
                "correct": False,
                "feedback": "Incorrect. Latency issues are related to computational efficiency, not the fundamental design challenge LSTMs address."
            }
        ]
    }]

# %%
display_quiz(q2)
# Out:
# <div id="FhJhxFyYuKgK" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #FhJhxFyYuKgK {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(q2, "q2")
# Out:
# '<span style="display:none" id="q2">...</span>'

# %%
display_quiz("#q2")
# Out:
# <div id="TRlmwPHmtdsz" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #TRlmwPHmtdsz {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
q3 = [{
        "question": "In an LSTM cell, what is the role of the forget gate?",
        "type": "many_choice",
        "answers": [
            {
                "answer": "It decides the information to be thrown away from the cell state.",
                "correct": True,
                "feedback": "Correct! The forget gate decides what information should be discarded from the cell state."
            },
            {
                "answer": "It updates the cell state with new information.",
                "correct": False,
                "feedback": "Incorrect. This is the role of the cell state update mechanism, not the forget gate."
            },
            {
                "answer": "It predicts the next output in the sequence.",
                "correct": False,
                "feedback": "Incorrect. The output gate handles the output, not the forget gate."
            },
            {
                "answer": "It decides what part of the cell state to read.",
                "correct": False,
                "feedback": "Incorrect. This is more closely related to the output gate's functionality."
            }
        ]
    }]

# %%
display_quiz(q3)
# Out:
# <div id="ijNCYJIdTBfs" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #ijNCYJIdTBfs {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(q3, "q3")
# Out:
# '<span style="display:none" id="q3">...</span>'

# %%
display_quiz("#q3")
# Out:
# <div id="gvZbZVgspelO" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #gvZbZVgspelO {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
q4 = [{
        "question": "What are the typical components of an LSTM cell?",
        "type": "many_choice",
        "answers": [
            {
                "answer": "Input gate, output gate, and cell state",
                "correct": False,
                "feedback": "Incorrect. You're missing one critical component."
            },
            {
                "answer": "Input gate, forget gate, output gate, and cell state",
                "correct": True,
                "feedback": "Correct! An LSTM cell typically consists of these components."
            },
            {
                "answer": "Cell state and hidden state only",
                "correct": False,
                "feedback": "Incorrect. An LSTM cell has more components than just the cell state and hidden state."
            },
            {
                "answer": "Input gate and output gate",
                "correct": False,
                "feedback": "Incorrect. These are just parts of the entire structure of an LSTM cell."
            }
        ]
    }]

# %%
display_quiz(q4)
# Out:
# <div id="cINAIZhHgdyo" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #cINAIZhHgdyo {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(q4, "q4")
# Out:
# '<span style="display:none" id="q4">...</span>'

# %%
display_quiz("#q4")
# Out:
# <div id="QQAbfrCNkHri" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #QQAbfrCNkHri {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
q5 = [ {
        "question": "How many main gates are there in a standard LSTM unit?",
        "type": "numeric",
        "precision": 0,  # Checking for an exact integer answer
        "answers": [
            {
                "type": "value",
                "value": 2,
                "correct": False,
                "feedback": "Incorrect. Remember to count all the main types of gates in an LSTM unit."
            },
            {
                "type": "value",
                "value": 3,
                "correct": True,
                "feedback": "Correct. A standard LSTM unit has three main gates: input, forget, and output gates."
            },
            {
                "type": "value",
                "value": 4,
                "correct": False,
                "feedback": "Incorrect. While there is another component for cell state updates, it's not typically counted as a 'gate'."
            },
            {
                "type": "default",
                "feedback": "Remember, LSTMs have three main gates to regulate the flow of information."
            }
        ]
    }]

# %%
display_quiz(q5)
# Out:
# <div id="fjGBdAlOXjCf" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #fjGBdAlOXjCf {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
get_spanned_encoded_q(q5, "q5")
# Out:
# '<span style="display:none" id="q5">...</span>'

# %%
display_quiz("#q5")
# Out:
# <div id="RJfUhgmfGNXi" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #RJfUhgmfGNXi {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
print("bvfdjfk")
